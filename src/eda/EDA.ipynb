# %% [markdown]
# Performing EDA
#
# Fetch artifact from wandb and read in as dataframe with pandas

# %%
 import wandb
 import pandas as pd

 run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
 local_path = wandb.use_artifact("sample.csv:latest").file()
 df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: ab-elix176. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.4
# Run data is saved locally in <code>/home/felix/projects/udacity/mlops/build-ml-pipeline-for-short-term-rental-prices/src/eda/wandb/run-20230608_104120-rrzhlf8o</code>
# Syncing run <strong><a href='https://wandb.ai/ab-elix176/nyc_airbnb/runs/rrzhlf8o' target="_blank">winter-pyramid-5</a></strong> to <a href='https://wandb.ai/ab-elix176/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ab-elix176/nyc_airbnb' target="_blank">https://wandb.ai/ab-elix176/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/ab-elix176/nyc_airbnb/runs/rrzhlf8o' target="_blank">https://wandb.ai/ab-elix176/nyc_airbnb/runs/rrzhlf8o</a>

# %%
# !pip install ydata_profiling
# Out:
# Collecting ydata_profiling
#   Downloading ydata_profiling-4.2.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.3/352.3 kB 2.2 MB/s eta 0:00:001.7 MB/s eta 0:00:01
# Requirement already satisfied: scipy<1.11,>=1.4.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (1.10.1)
# Collecting pandas!=1.4.0,<2,>1.1 (from ydata_profiling)
#   Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: matplotlib<4,>=3.2 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (3.7.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (1.10.9)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (3.1.2)
# Collecting visions[type_image_path]==0.7.5 (from ydata_profiling)
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 3.4 MB/s eta 0:00:00
# Collecting numpy<1.24,>=1.16.0 (from ydata_profiling)
#   Downloading numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 6.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: htmlmin==0.1.12 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (1.9.1)
# Collecting statsmodels<1,>=0.13.2 (from ydata_profiling)
#   Downloading statsmodels-0.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 1.2 MB/s eta 0:00:00m eta 0:00:0136m0:00:010m
# Collecting typeguard<3,>=2.13.2 (from ydata_profiling)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: imagehash==4.3.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from ydata_profiling) (4.3.1)
# Collecting wordcloud>=1.9.1 (from ydata_profiling)
#   Downloading wordcloud-1.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (473 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.1/473.1 kB 1.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting dacite>=1.8 (from ydata_profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: PyWavelets in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from imagehash==4.3.1->ydata_profiling) (1.4.1)
# Requirement already satisfied: pillow in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from imagehash==4.3.1->ydata_profiling) (9.5.0)
# Requirement already satisfied: attrs>=19.3.0 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from visions[type_image_path]==0.7.5->ydata_profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from visions[type_image_path]==0.7.5->ydata_profiling) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from visions[type_image_path]==0.7.5->ydata_profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from matplotlib<4,>=3.2->ydata_profiling) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from matplotlib<4,>=3.2->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from matplotlib<4,>=3.2->ydata_profiling) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from matplotlib<4,>=3.2->ydata_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from matplotlib<4,>=3.2->ydata_profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from matplotlib<4,>=3.2->ydata_profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from matplotlib<4,>=3.2->ydata_profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from pandas!=1.4.0,<2,>1.1->ydata_profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from pydantic<2,>=1.8.1->ydata_profiling) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling) (2023.5.7)
# Collecting patsy>=0.5.2 (from statsmodels<1,>=0.13.2->ydata_profiling)
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 917.2 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: six in /home/felix/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata_profiling) (1.16.0)
# Installing collected packages: typeguard, numpy, dacite, patsy, pandas, visions, statsmodels, wordcloud, ydata_profiling
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.2
#     Uninstalling pandas-2.0.2:
#       Successfully uninstalled pandas-2.0.2
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.5 which is incompatible.
# Successfully installed dacite-1.8.1 numpy-1.23.5 pandas-1.5.3 patsy-0.5.3 statsmodels-0.14.0 typeguard-2.13.3 visions-0.7.5 wordcloud-1.9.2 ydata_profiling-4.2.0

# %%
import ydata_profiling

profile = ydata_profiling.ProfileReport(df)
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11147/2348844260.py in ?()
#       1 import ydata_profiling
#       2
#       3 profile = ydata_profiling.ProfileReport(df)
# ----> 4 profile.to_notebook_iframe()
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/profile_report.py in ?(self)
#     494
#     495         # Ignore warning: https://github.com/ipython/ipython/pull/11350/files
#     496         with warnings.catch_warnings():
#     497             warnings.simplefilter("ignore")
# --> 498             display(get_notebook_iframe(self.config, self))
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/report/presentation/flavours/widget/notebook.py in ?(config, profile)
#      71     attribute = config.notebook.iframe.attribute
#      72     if attribute == IframeAttribute.src:
#      73         output = get_notebook_iframe_src(config, profile)
#      74     elif attribute == IframeAttribute.srcdoc:
# ---> 75         output = get_notebook_iframe_srcdoc(config, profile)
#      76     else:
#      77         raise ValueError(
#      78             f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/report/presentation/flavours/widget/notebook.py in ?(config, profile)
#      25     from IPython.core.display import HTML
#      26
#      27     width = config.notebook.iframe.width
#      28     height = config.notebook.iframe.height
# ---> 29     src = html.escape(profile.to_html())
#      30
#      31     iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      32
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/profile_report.py in ?(self)
#     464         Returns:
#     465             Profiling report html including wrapper.
#     466
#     467         """
# --> 468         return self.html
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/profile_report.py in ?(self)
#     272     @property
#     273     def html(self) -> str:
#     274         if self._html is None:
# --> 275             self._html = self._render_html()
#     276         return self._html
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/profile_report.py in ?(self)
#     380     def _render_html(self) -> str:
#     381         from ydata_profiling.report.presentation.flavours import HTMLReport
#     382
# --> 383         report = self.report
#     384
#     385         with tqdm(
#     386             total=1, desc="Render HTML", disable=not self.config.progress_bar
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/profile_report.py in ?(self)
#     266     @property
#     267     def report(self) -> Root:
#     268         if self._report is None:
# --> 269             self._report = get_report_structure(self.config, self.description_set)
#     270         return self._report
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/typeguard/__init__.py in ?(*args, **kwargs)
#    1030     def wrapper(*args, **kwargs):
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#    1036         except TypeError as exc:
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/profile_report.py in ?(self)
#     248     @property
#     249     def description_set(self) -> BaseDescription:
#     250         if self._description_set is None:
# --> 251             self._description_set = describe_df(
#     252                 self.config,
#     253                 self.df,
#     254                 self.summarizer,
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/model/describe.py in ?(config, df, summarizer, typeset, sample)
#     131
#     132         # missing diagrams
#     133         missing_map = get_missing_active(config, table_stats)
#     134         pbar.total += len(missing_map)
# --> 135         missing = {
#     136             name: progress(get_missing_diagram, pbar, f"Missing diagram {name}")(
#     137                 config, df, settings
#     138             )
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/model/describe.py in ?(.0)
#     135 def describe(
# --> 136     config: Settings,
#     137     df: pd.DataFrame,
#     138     summarizer: BaseSummarizer,
#     139     typeset: VisionsTypeset,
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/utils/progress_bar.py in ?(*args, **kwargs)
#       8     @wraps(fn)
#       9     def inner(*args, **kwargs) -> Any:
#      10         bar.set_postfix_str(message)
# ---> 11         ret = fn(*args, **kwargs)
#      12         bar.update()
#      13         return ret
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/model/missing.py in ?(config, df, settings)
#     108
#     109     if len(df) == 0:
#     110         return None
#     111
# --> 112     result = handle_missing(settings["name"], settings["function"])(config, df)
#     113     if result is None:
#     114         return None
#     115
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/model/missing.py in ?(*args, **kwargs)
#      85             )
#      86
#      87         try:
#      88             return fn(*args, *kwargs)
# ---> 89         except ValueError as e:
#      90             warn_missing(name, str(e))
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/multimethod/__init__.py in ?(self, *args, **kwargs)
#     312             self.evaluate()
#     313         func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314         try:
#     315             return func(*args, **kwargs)
# --> 316         except TypeError as ex:
#     317             raise DispatchError(f"Function {func.__code__}") from ex
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/model/pandas/missing_pandas.py in ?(config, df)
#      13 @missing_bar.register
#      14 def pandas_missing_bar(config: Settings, df: pd.DataFrame) -> str:
#      15     notnull_counts = len(df) - df.isnull().sum()
# ---> 16     return plot_missing_bar(
#      17         config,
#      18         notnull_counts=notnull_counts,
#      19         nrows=len(df),
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/contextlib.py in ?(*args, **kwds)
#      78         @wraps(func)
#      79         def inner(*args, **kwds):
#      80             with self._recreate_cm():
# ---> 81                 return func(*args, **kwds)
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/visualisation/missing.py in ?(config, notnull_counts, nrows, columns)
#      80
#      81     Returns:
#      82         The resulting missing values bar plot encoded as a string.
#      83     """
# ---> 84     missing_bar(
#      85         notnull_counts=notnull_counts,
#      86         nrows=nrows,
#      87         figsize=(10, 5),
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/ydata_profiling/visualisation/plot.py in ?(notnull_counts, nrows, figsize, fontsize, labels, color, label_rotation)
#     809     """
#     810     percentage = notnull_counts / nrows
#     811
#     812     if len(notnull_counts) <= 50:
# --> 813         ax0 = percentage.plot.bar(figsize=figsize, fontsize=fontsize, color=color)
#     814         ax0.set_xticklabels(
#     815             ax0.get_xticklabels(),
#     816             ha="right",
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/pandas/plotting/_core.py in ?(self, x, y, **kwargs)
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/pandas/plotting/_core.py in ?(self, *args, **kwargs)
#     971             warnings.warn(
#     972                 "`sort_columns` is deprecated and will be removed in a future "
#     973                 "version.",
#     974                 FutureWarning,
# --> 975                 stacklevel=find_stack_level(),
#     976             )
#     977
#     978         if args and isinstance(data, ABCSeries):
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py in ?(data, kind, **kwargs)
#      67             with plt.rc_context():
#      68                 ax = plt.gca()
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py in ?(self)
#     448     def generate(self) -> None:
#     449         self._args_adjust()
# --> 450         self._compute_plot_data()
#     451         self._setup_subplots()
#     452         self._make_plot()
#     453         self._add_table()
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py in ?(self)
#     604             data = reconstruct_data_with_by(self.data, by=self.by, cols=self.columns)
#     605
#     606         # GH16953, _convert is needed as fallback, for ``Series``
#     607         # with ``dtype == object``
# --> 608         data = data._convert(datetime=True, timedelta=True)
#     609         include_type = [np.number, "datetime", "datetimetz", "timedelta"]
#     610
#     611         # GH23719, allow plotting boolean
#
# ~/miniconda3/envs/mlflow-eb19349646cb4aa41445e6657559085c1ea27c54/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_convert'
